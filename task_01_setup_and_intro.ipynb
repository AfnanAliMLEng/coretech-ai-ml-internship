# %% [markdown]
# Information
#
# Name: Afnan Ali
# Education: 2nd Year IT Student
# City: Kazi Ahmed, Sindh, Pakistan
# Skills: Python, Basic Programming, Problem Solving, GitHub
#
# Learning Goal:
# I want to learn Artificial Intelligence and Machine Learning to develop intelligent applications and improve my technical skills.

# %% [markdown]
# 1. What is Artificial Intelligence (AI)?
# Artificial Intelligence (AI) is a branch of computer science that enables machines to perform tasks that normally require human intelligence, such as learning, reasoning, decision-making, and problem-solving.
#
# 2. What is Machine Learning (ML)?
# Machine Learning (ML) is a subset of Artificial Intelligence that allows computers to learn from data and improve their performance without being explicitly programmed for every task.
#
# 3. What is Deep Learning (DL)?
# Deep Learning (DL) is a specialized branch of Machine Learning that uses multi-layered neural networks to learn complex patterns from large amounts of data.
#
# 4. Difference Between AI, ML, and DL
# AI: The broad concept of creating intelligent machines.
# ML: A subset of AI that learns from data.
# DL: A subset of ML that uses deep neural networks for advanced learning tasks.
#
# Hierarchy: AI → ML → DL
#
# 5. How AI/ML Can Help CoreTech Innovation?
# - Automating repetitive tasks.
# - Improving decision-making through data analysis.
# - Enhancing customer support with intelligent chatbots.
# - Predicting trends and future outcomes.
# - Increasing efficiency and productivity.
# - Developing smart and innovative software solutions.

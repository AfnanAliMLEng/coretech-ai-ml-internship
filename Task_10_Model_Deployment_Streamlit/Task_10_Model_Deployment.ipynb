# %% [markdown]
# # Task 10: AI Model Deployment with Streamlit
#
# ## Project Status Prediction Web Application
#
# This project is a continuation of Task 09: Model Optimization and Hyperparameter Tuning.
#
# The optimized Random Forest model developed and validated in the previous task is deployed using Streamlit to create an interactive web application. The application allows users to enter project-related information and receive real-time project status predictions.
#
# Instead of retraining the model, the previously optimized model is loaded from a saved file and integrated into a user-friendly deployment environment.
#
# ### Project Objectives
#
# - Reuse the optimized Random Forest model from Task 09.
# - Save and load the trained model using Joblib.
# - Develop an interactive Streamlit web application.
# - Accept user input through a web interface.
# - Generate real-time project status predictions.

# %% [markdown]
# # Import Required Libraries
#
# The following libraries are used to load the trained machine learning model and test its prediction functionality before deployment.

# %%
import pandas as pd
import numpy as np
import joblib

# %% [markdown]
# # Load Trained Model
#
# The optimized Random Forest model developed in Task 09 is loaded using Joblib. This allows the model to be reused without retraining.

# %%
model = joblib.load(
    "project_status_model.pkl"
)

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %% [markdown]
# ### Model Loading Interpretation
#
# The trained model was successfully loaded from the saved file. This confirms that the deployment process can reuse the optimized model without repeating the training and optimization stages.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# # Model Prediction Testing
#
# Before deployment, a sample project record is used to verify that the model can generate predictions correctly.

# %%
sample = [[

    150,       # Employees

    750000,    # Annual Revenue

    40,        # Projects Completed

    6,         # Years With Company

    90         # Customer Satisfaction

]]

prediction = model.predict(
    sample
)

print(
    "Predicted Status:",
    prediction
)
# Out:
# Predicted Status: [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Prediction Verification
#
# The model successfully generated a prediction for the sample project data. This confirms that the saved model is functioning correctly and is ready for deployment within the Streamlit application.

# %% [markdown]
# -------------------------------------------------------------------------------------------------
# # Streamlit Application Development
#
# A web-based interface is developed using Streamlit. Users can enter project-related information through input fields and receive real-time project status predictions generated by the trained machine learning model.

# %%
# %%writefile app.py

import streamlit as st
import joblib
import numpy as np

model = joblib.load(
    "project_status_model.pkl"
)

st.title(
    "CoreTech Project Status Predictor"
)

st.info(
    "This application predicts project status using an optimized Random Forest model developed during Task 09."
)

st.subheader(
    "AI-Powered Project Analytics Dashboard"
)

employees = st.number_input(
    "Employees"
)

annual_revenue = st.number_input(
    "Annual Revenue"
)

projects_completed = st.number_input(
    "Projects Completed"
)

years_with_company = st.number_input(
    "Years With Company"
)

customer_satisfaction = st.number_input(
    "Customer Satisfaction"
)

if st.button(
    "Predict Project Status"
):

    data = np.array([[

        employees,

        annual_revenue,

        projects_completed,

        years_with_company,

        customer_satisfaction

    ]])

    prediction = model.predict(
        data
    )

    st.success(
        f"Predicted Status: {prediction[0]}"
    )

st.markdown("---")

st.write(
    "Model Used: Optimized Random Forest"
)

st.write(
    "Source: Task 09 Model Optimization Project"
)
# Out:
# Writing app.py

# %% [markdown]
# ### Application Overview
#
# The application accepts project-related inputs from users and generates project status predictions using the optimized Random Forest model. This provides a practical example of machine learning deployment for business decision support.

# %% [markdown]
# # Requirements File
#
# The following dependencies are required to run the Streamlit application.

# %%
# %%writefile requirements.txt
#
# streamlit
# pandas
# numpy
# scikit-learn
# joblib
# Out:
# Writing requirements.txt

# %% [markdown]
# ### Dependency Management
#
# The requirements file ensures that all necessary libraries can be installed consistently when deploying the application on another system or cloud platform.

# %% [markdown]
# # Deployment File Verification
#
# The deployment files are verified before download and submission.

# %%
# !ls
# Out:
# app.py	project_status_model.pkl  requirements.txt  sample_data

# %% [markdown]
# # Download Deployment Files
#
# The following files are downloaded for GitHub submission and deployment purposes.

# %%
from google.colab import files

files.download(
    "app.py"
)

files.download(
    "requirements.txt"
)

files.download(
    "project_status_model.pkl"
)

# %% [markdown]
# # Deployment Instructions
#
# To run the application locally:
#
# 1. Install dependencies using requirements.txt
# 2. Place the trained model file in the project directory
# 3. Run the Streamlit application
# 4. Enter project information
# 5. Generate real-time project status predictions
#
# Command:
#
# streamlit run app.py

# %% [markdown]
# # Business Use Case
#
# This application can assist project managers in evaluating project health and predicting project outcomes based on business performance indicators.
#
# The deployment demonstrates how machine learning models can be transformed into practical decision-support tools that provide instant predictions through an interactive web interface.
